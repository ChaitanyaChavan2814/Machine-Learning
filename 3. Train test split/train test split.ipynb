# %%
import pandas as pd
df = pd.read_csv('carprices.csv')
df.head()
# Out:
#    Mileage  Age(yrs)  Sell Price($)
# 0    69000         6          18000
# 1    35000         3          34000
# 2    57000         5          26100
# 3    22500         2          40000
# 4    46000         4          31500

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Car Mileage Vs Sell Price ($)

# %%
plt.scatter(df['Mileage'],df['Sell Price($)'])
plt.xlabel('Mileage')
plt.ylabel('Sell Price ($)')
# Out:
# Text(0, 0.5, 'Sell Price ($)')

# %% [markdown]
# Car Age Vs Sell Price ($)

# %%
plt.scatter(df['Age(yrs)'],df['Sell Price($)'])
plt.xlabel('Age')
plt.ylabel('Sell Price ($)')
# Out:
# Text(0, 0.5, 'Sell Price ($)')

# %%
X = df[['Mileage','Age(yrs)']]
y = df['Sell Price($)']

# %%
X
# Out:
#     Mileage  Age(yrs)
# 0     69000         6
# 1     35000         3
# 2     57000         5
# 3     22500         2
# 4     46000         4
# 5     59000         5
# 6     52000         5
# 7     72000         6
# 8     91000         8
# 9     67000         6
# 10    83000         7
# 11    79000         7
# 12    59000         5
# 13    58780         4
# 14    82450         7
# 15    25400         3
# 16    28000         2
# 17    69000         5
# 18    87600         8
# 19    52000         5

# %%
y
# Out:
# 0     18000
# 1     34000
# 2     26100
# 3     40000
# 4     31500
# 5     26750
# 6     32000
# 7     19300
# 8     12000
# 9     22000
# 10    18700
# 11    19500
# 12    26000
# 13    27500
# 14    19400
# 15    35000
# 16    35500
# 17    19700
# 18    12800
# 19    28200
# Name: Sell Price($), dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2)
# Use random state=10 to keep the train sample fixed

# %%
len(X_train)
# Out:
# 16

# %%
len(X_test)
# Out:
# 4

# %%
X_train
# Out:
#     Mileage  Age(yrs)
# 11    79000         7
# 10    83000         7
# 3     22500         2
# 16    28000         2
# 8     91000         8
# 15    25400         3
# 13    58780         4
# 1     35000         3
# 17    69000         5
# 4     46000         4
# 14    82450         7
# 0     69000         6
# 2     57000         5
# 5     59000         5
# 6     52000         5
# 9     67000         6

# %%
from sklearn.linear_model import LinearRegression
clf = LinearRegression()

# %%
clf.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
clf.predict(X_test)
# Out:
# array([15431.44723032, 25664.46243753, 28107.52965906, 21043.55741113])

# %%
y_test
# Out:
# 18    12800
# 12    26000
# 19    28200
# 7     19300
# Name: Sell Price($), dtype: int64

# %%
clf.score(X_test, y_test)
# Out:
# 0.9307530634465648
